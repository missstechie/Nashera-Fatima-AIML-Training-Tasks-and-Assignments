# %% [markdown]
# <a href="https://colab.research.google.com/github/missstechie/Nashera-Fatima-AIML-Training-Tasks-and-Assignments/blob/main/Copy_of_STP_Module_01_Lab_04_Transforming_data_using_linear_algebra_by_Om.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transforming data using linear algebra
#
# Module 1, Lab 4
#
# Matrix transformations are at the heart of many machine learning algorithms. In this lab, we'll visualize the effect of some simple transformations on a unit square and then visualize it using the MNIST dataset. We also see what data normalization means and how it can help in improving the accuracy of machine learning models.

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist

# %%
# You don't need to understand these functions


def plotGrid(transform, unit, linestyle=":", fig=None, ax=None):
    lim1 = -100
    lim2 = 100

    def mat2xy(start, end):
        if len(start.shape) == 1:
            start = np.expand_dims(start, 0)
            end = np.expand_dims(end, 0)
        nan = np.ones(len(start)) * np.nan
        x = np.stack((start[:, 0], end[:, 0], nan)).T.reshape(-1)
        y = np.stack((start[:, 1], end[:, 1], nan)).T.reshape(-1)
        return x, y

    def parallellines(axis, addend, lines, unit):
        addend = np.repeat(np.expand_dims(addend, 0), lines * 2, 0)
        unit = np.expand_dims(np.arange(-lines, lines) * unit, 1)
        unit = unit - lines
        addend = addend * unit
        lines = np.expand_dims(axis, 0) + addend
        return np.concatenate((lines, lines * -1))

    if fig is None:
        fig, ax = plt.subplots(figsize=(5, 5))
    transform = transform.astype(float)
    xaxis = transform[0]
    yaxis = transform[1]

    # plot lines parallel to the x axis
    lines1 = parallellines(xaxis * lim1, yaxis, 100, unit)
    lines2 = parallellines(xaxis * lim2, yaxis, 100, unit)
    x, y = mat2xy(lines1, lines2)
    plt.plot(x, y, linestyle + "k", linewidth=0.5)
    # plot x axis
    x, y = mat2xy(xaxis * lim1, xaxis * lim2)
    plt.plot(x, y, linestyle, color="#440077")

    # plot  lines parallel to the y axis
    lines1 = parallellines(yaxis * lim1, xaxis, 100, unit)
    lines2 = parallellines(yaxis * lim2, xaxis, 100, unit)
    x, y = mat2xy(lines1, lines2)
    plt.plot(x, y, linestyle + "k", linewidth=0.5)
    # plot y axis
    x, y = mat2xy(yaxis * lim1, yaxis * lim2)
    plt.plot(x, y, linestyle, color="#aa5500")

    return fig, ax


def plotData(X, y, xlabel="hole", ylabel="bound", fig=None, ax=None):
    if fig is None:
        fig, ax = plt.subplots()
    for ii in range(nclasses):
        plt.scatter(X[y == ii, 0], X[y == ii, 1])
    plt.legend([str(i) for i in range(nclasses)])
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    lim2 = X.max()
    lim1 = X.min()
    return fig, ax

# %% [markdown]
# ## Matrix transformations on data
#
# Note: This lab involves a lot of matrix operations. If you are not familiar with them, please go through the resources given in class before proceeding. You can also review Khan Academy's excellent linear algebra [resources](https://www.khanacademy.org/math/linear-algebra/matrix-transformations).
#
# A 2D coordinate system is defined by its basis vectors, i and j. Any point in this 2D space can be represented as a linear combination of these basis vectors. For example, the point (a,b) can be represented as:
#
# $$\begin{equation}
# \left\{  \begin{aligned}a \\ b \end{aligned} \right\} = a\left\{  \begin{aligned}1 \\ 0 \end{aligned} \right\} + b\left\{  \begin{aligned}0 \\ 1 \end{aligned} \right\} = a\hat{i} + b\hat{j}
# \end{equation}$$
#
# A matrix can be used to perform a linear transformation on the basis vectors. The new basis vectors $\hat{i}$ and $\hat{j}$ are given by the product of the matrix and the basis vectors of the standard coordinate system.
#
# In the standard coordinate system (Let us call it T0), the basis vectors are
#
# $$\begin{equation}
# i = \left\{  \begin{aligned}1 \\ 0 \end{aligned} \right\}
# \end{equation}$$
# and
# $$\begin{equation} j = \left\{ \begin{aligned} 0 \\ 1\end{aligned} \right\} \end{equation}$$
#
# We can use any two vectors as basis vectors for a new coordinate system as long as they are not colinear. For example, let us call this new coordinate system T1:
#
# $$\begin{equation}
# i = \left\{  \begin{aligned}1 \\ -1 \end{aligned} \right\}
# \end{equation}$$
# and
# $$\begin{equation} j = \left\{ \begin{aligned} 0 \\ 2 \end{aligned} \right\} \end{equation}$$
#
# Suppose we have a point [a,b] in the T1 coordinate system. Its representation in the standard system T0 can be obtained by the following matrix multiplication:
#
# $$ \begin{equation}
# \left\{  \begin{aligned}a' \\ b' \end{aligned} \right\} =
# \left\{  \begin{aligned}&1 & 0 \\ -&1 & 2 \end{aligned} \right\}
# \left\{  \begin{aligned}a \\ b \end{aligned} \right\}
# \end{equation}$$
# where the columns of the matrix are the basis vectors of T1.
#
#
# Let us see this in action:

# %%
T0 = np.array([[1, 0], [0, 1]])
T1 = np.array([[1, 0], [-1, 2]])

data1 = np.array([7, 2])  # the data in T1 coordinate system
data0 = np.matmul(T1, data1)  # the data in T0 coordinate system

print("Data in T0 = ", data0)
print("Data in T1 = ", data1)
# Out:
# Data in T0 =  [ 7 -3]
# Data in T1 =  [7 2]

# %% [markdown]
# We can visualize this below. T0 is shown with dotted lines and T1 is shown with solid lines.

# %%
fig, ax = plotGrid(T1.T, 1, "-")
plotGrid(T0.T, 1, fig=fig, ax=ax)

plt.scatter(data0[0], data0[1])
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
ax.set_xticks([])
ax.set_yticks([])
plt.show()

# %% [markdown]
# ### What Are Basis Vectors?
#
# Think of basis vectors as the **"rulers"** of your coordinate system. Just like measuring distance in meters vs feet changes the numbers but not the actual distance, different basis vectors represent the same point differently.
#
# **Standard Coordinate System (T0):**
# - Basis vectors: **î** = [1, 0] and **ĵ** = [0, 1]
# - Point [5, 3] means: "5 steps along x-axis, 3 steps along y-axis"
#
# **Transformed Coordinate System (T1):**
# - Basis vectors: **î** = [1, -1] and **ĵ** = [0, 2]
# - Point [5, 4] in T1 = Point [5, 3] in T0 (same location, different description!)
#
# ---
#
# ### Matrix Transformation Formula
#
# Converting from T1 to T0:
#
# $$\begin{bmatrix} x_{T0} \\ y_{T0} \end{bmatrix} = \begin{bmatrix} \text{î}_x & \text{ĵ}_x \\ \text{î}_y & \text{ĵ}_y \end{bmatrix} \begin{bmatrix} x_{T1} \\ y_{T1} \end{bmatrix}$$
#
# Where columns of the matrix are the basis vectors of T1.
#
# **Example:**
# $$\begin{bmatrix} 5 \\ 3 \end{bmatrix} = \begin{bmatrix} 1 & 0 \\ -1 & 2 \end{bmatrix} \begin{bmatrix} 5 \\ 4 \end{bmatrix}$$
#
# ---

# %% [markdown]
# Look at the coordinates of the blue dot. In T0 (dotted lines), the position is [5,3] where it is [5,4] in T1. Feel free to experiment with different data points and coordinate systems.
#
# Remember that we can achieve the same thing by post-multiplying the transpose of the transformation matrix to the data. This will come in handy when transforming multiple data points at once:

# %%
data0_a = np.matmul(T1, data1)
data0_b = np.matmul(data1, T1.T)
print(data0_a)
print(data0_b)
# Out:
# [ 7 -3]
# [ 7 -3]

# %% [markdown]
# Why is transforming data useful? Data transformations cause the distance between data points to change. This will affect distance-based algorithms such as nearest neighbour

# %%
# let us define 3 points in T1
A1 = np.array([3, 3])
B1 = np.array([2, -5])
C1 = np.array([1, -1])

# the corresponding points in T0:
A0 = np.matmul(T1, A1)
B0 = np.matmul(T1, B1)
C0 = np.matmul(T1, C1)


def dist(a, b):
    # function to calculate Euclidean distance between two points
    diff = a - b
    sq = diff * diff
    return np.sqrt(sq.sum())


# distance between the points in T1
print("Distance between A and B in T1 = ", dist(A1, B1))
print("Distance between B and C in T1 = ", dist(B1, C1))
print("Distance between A and C in T1 = ", dist(A1, C1))

print("")
# distnace between the points in T0
print("Distance between A and B in T0 = ", dist(A0, B0))
print("Distance between B and C in T0 = ", dist(B0, C0))
print("Distance between A and C in T0 = ", dist(A0, C0))
# Out:
# Distance between A and B in T1 =  8.06225774829855
# Distance between B and C in T1 =  4.123105625617661
# Distance between A and C in T1 =  4.47213595499958
#
# Distance between A and B in T0 =  15.033296378372908
# Distance between B and C in T0 =  9.055385138137417
# Distance between A and C in T0 =  6.324555320336759

# %% [markdown]
# We see that in T1, B and C are the closest whereas in T0, A and C are the closest. These kinds of changes will affect the predictions returned by the nearest neighbour algorithm.

# %%
# Visualize how transformation changes point relationships
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot in T1 (original space)
ax1.scatter([A1[0], B1[0], C1[0]], [A1[1], B1[1], C1[1]],
            s=200, c=['red', 'blue', 'green'], alpha=0.7)
ax1.plot([A1[0], B1[0]], [A1[1], B1[1]], 'k--', linewidth=2, label='A-B')
ax1.plot([B1[0], C1[0]], [B1[1], C1[1]], 'k:', linewidth=2, label='B-C')
ax1.plot([A1[0], C1[0]], [A1[1], C1[1]], 'k-.', linewidth=2, label='A-C')
ax1.scatter([A1[0], B1[0], C1[0]], [A1[1], B1[1], C1[1]],
            s=200, c=['red', 'blue', 'green'], alpha=0.7)
ax1.text(A1[0]+0.3, A1[1]+0.3, 'A', fontsize=14, fontweight='bold')
ax1.text(B1[0]+0.3, B1[1]+0.3, 'B', fontsize=14, fontweight='bold')
ax1.text(C1[0]+0.3, C1[1]+0.3, 'C', fontsize=14, fontweight='bold')
ax1.set_title('Original Space (T1)\nB-C are closest', fontsize=12, fontweight='bold')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.grid(True, alpha=0.3)
ax1.legend()
ax1.axis('equal')

# Plot in T0 (transformed space)
ax2.scatter([A0[0], B0[0], C0[0]], [A0[1], B0[1], C0[1]],
            s=200, c=['red', 'blue', 'green'], alpha=0.7)
ax2.plot([A0[0], B0[0]], [A0[1], B0[1]], 'k--', linewidth=2, label='A-B')
ax2.plot([B0[0], C0[0]], [B0[1], C0[1]], 'k:', linewidth=2, label='B-C')
ax2.plot([A0[0], C0[0]], [A0[1], C0[1]], 'k-.', linewidth=2, label='A-C')
ax2.text(A0[0]+0.3, A0[1]+0.3, 'A', fontsize=14, fontweight='bold')
ax2.text(B0[0]+0.3, B0[1]+0.3, 'B', fontsize=14, fontweight='bold')
ax2.text(C0[0]+0.3, C0[1]+0.3, 'C', fontsize=14, fontweight='bold')
ax2.set_title('Transformed Space (T0)\nA-C are closest', fontsize=12, fontweight='bold')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.grid(True, alpha=0.3)
ax2.legend()
ax2.axis('equal')

plt.tight_layout()
plt.show()

# Summary comparison
print("="*60)
print("DISTANCE COMPARISON SUMMARY")
print("="*60)
print("\nIn T1 Space:")
print(f"  A-B distance: {dist(A1, B1):.2f}")
print(f"  B-C distance: {dist(B1, C1):.2f} ← SHORTEST")
print(f"  A-C distance: {dist(A1, C1):.2f}")

print("\nIn T0 Space (after transformation):")
print(f"  A-B distance: {dist(A0, B0):.2f}")
print(f"  B-C distance: {dist(B0, C0):.2f}")
print(f"  A-C distance: {dist(A0, C0):.2f} ← SHORTEST")

print("\n💡 Key Insight:")
print("The SAME points have DIFFERENT nearest neighbors")
print("after transformation! This directly affects K-NN predictions.")
print("="*60)
# Out:
# ============================================================
# DISTANCE COMPARISON SUMMARY
# ============================================================
#
# In T1 Space:
#   A-B distance: 8.06
#   B-C distance: 4.12 ← SHORTEST
#   A-C distance: 4.47
#
# In T0 Space (after transformation):
#   A-B distance: 15.03
#   B-C distance: 9.06
#   A-C distance: 6.32 ← SHORTEST
#
# 💡 Key Insight:
# The SAME points have DIFFERENT nearest neighbors
# after transformation! This directly affects K-NN predictions.
# ============================================================

# %% [markdown]
# ## Transformations on MNIST
#
# Let us experiment with a subset of the MNIST dataset. We will extract two features from the database for our experiment. We will then transform the data using a transformation matrix and visualize the data in the new coordinate system. We will also see how normalization can help in improving the accuracy of the model. We will reuse previous labs code for this.

# %%
def NN1(traindata, trainlabel, query):
    """
    This function takes in the training data, training labels and a query point
    and returns the predicted label for the query point using the nearest neighbour algorithm

    traindata: numpy array of shape (n,d) where n is the number of samples and d is the number of features
    trainlabel: numpy array of shape (n,) where n is the number of samples
    query: numpy array of shape (d,) where d is the number of features

    returns: the predicted label for the query point which is the label of the training data which is closest to the query point
    """
    diff = (
        traindata - query
    )  # find the difference between features. Numpy automatically takes care of the size here
    sq = diff * diff  # square the differences
    dist = sq.sum(1)  # add up the squares
    label = trainlabel[np.argmin(dist)]
    return label


def NN(traindata, trainlabel, testdata):
    """
    This function takes in the training data, training labels and test data
    and returns the predicted labels for the test data using the nearest neighbour algorithm

    traindata: numpy array of shape (n,d) where n is the number of samples and d is the number of features
    trainlabel: numpy array of shape (n,) where n is the number of samples
    testdata: numpy array of shape (m,d) where m is the number of test samples and d is the number of features

    returns: the predicted labels for the test data which is the label of the training data which is closest to each test point
    """
    predlabel = np.array([NN1(traindata, trainlabel, i) for i in testdata])
    return predlabel


def Accuracy(gtlabel, predlabel):
    """
    This function takes in the ground-truth labels and predicted labels
    and returns the accuracy of the classifier

    gtlabel: numpy array of shape (n,) where n is the number of samples
    predlabel: numpy array of shape (n,) where n is the number of samples

    returns: the accuracy of the classifier which is the number of correct predictions divided by the total number of predictions
    """
    assert len(gtlabel) == len(
        predlabel
    ), "Length of the ground-truth labels and predicted labels should be the same"
    correct = (
        gtlabel == predlabel
    ).sum()  # count the number of times the groundtruth label is equal to the predicted label.
    return correct / len(gtlabel)


def cumArray(img):
    img2 = img.copy()
    for ii in range(1, img2.shape[1]):
        # for every row, add up all the rows above it.
        img2[ii, :] = img2[ii, :] + img2[ii - 1, :]
    img2 = img2 > 0
    return img2


def getHolePixels(img):
    """
    This function takes in a binary image and returns the pixels that are holes in the image

    img: numpy array of shape (n,m) where n is the height of the image and m is the width of the image

    returns: a binary image of the same shape as the input image where the holes are filled in
    """
    im1 = cumArray(img)
    # rotate and cumulate it again for differnt direction
    im2 = np.rot90(cumArray(np.rot90(img)), 3)
    im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
    im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
    # this will create a binary image with all the holes filled in.
    hull = im1 & im2 & im3 & im4
    # remove the original digit to leave behind the holes
    hole = hull & ~(img > 0)
    return hole


def getHullPixels(img):
    """
    This function takes in a binary image and returns the pixels that are the convex hull of the image

    img: numpy array of shape (n,m) where n is the height of the image and m is the width of the image

    returns: a binary image of the same shape as the input image where the convex hull is filled in
    """
    im1 = cumArray(img)
    # rotate and cumulate it again for differnt direction
    im2 = np.rot90(cumArray(np.rot90(img)), 3)
    im3 = np.rot90(cumArray(np.rot90(img, 2)), 2)
    im4 = np.rot90(cumArray(np.rot90(img, 3)), 1)
    # this will create a binary image with all the holes filled in.
    hull = im1 & im2 & im3 & im4
    return hull


def minus(a, b):
    """
    This function takes in two binary images and returns the difference between the two images
    """
    return a & ~b


def getBoundaryPixels(img):
    """
    This function takes in a binary image and returns the pixels that are the boundary of the image

    img: numpy array of shape (n,m) where n is the height of the image and m is the width of the image

    returns: a binary image of the same shape as the input image where the boundary is filled in
    """
    img = img.copy() > 0  # binarize the image
    rshift = np.roll(img, 1, 1)
    lshift = np.roll(img, -1, 1)
    ushift = np.roll(img, -1, 0)
    dshift = np.roll(img, 1, 0)
    boundary = (
        minus(img, rshift)
        | minus(img, lshift)
        | minus(img, ushift)
        | minus(img, dshift)
    )
    return boundary

# %%
# loading the dataset
(train_X, train_y), (test_X, test_y) = mnist.load_data()
train_X = train_X / 255
test_X = test_X / 255

nclasses = 4

# get only for the first 4 classes
train_X = train_X[train_y < nclasses]
train_y = train_y[train_y < nclasses]
test_X = test_X[test_y < nclasses]
test_y = test_y[test_y < nclasses]

# We are only taking a subset of the training set
train_X = train_X[::100].copy()
train_y = train_y[::100].copy()  # do the same to the labels

# taking a subset of the test set. This code takes every 500th sample
test_X = test_X[::100].copy()
test_y = test_y[::100].copy()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# feature extraction
train_hole = np.array([getHolePixels(i).sum() for i in train_X])
test_hole = np.array([getHolePixels(i).sum() for i in test_X])
train_bound = np.array([getBoundaryPixels(i).sum() for i in train_X])
test_bound = np.array([getBoundaryPixels(i).sum() for i in test_X])
# train_hull = np.array([getHullPixels(i).sum() for i in train_X])
# test_hull = np.array([getHullPixels(i).sum() for i in test_X])
# train_sum = np.sum(train_X, (1, 2)) / (28 * 28)
# test_sum = np.sum(test_X, (1, 2)) / (28 * 28)

# create the train and test set by combining the appropriate features
train_feats = np.vstack(
    (train_hole, train_bound)).transpose()
test_feats = np.vstack(
    (test_hole, test_bound)).transpose()

# %% [markdown]
# Let us plot the samples and see what they look like:

# %%
# fix limits of x and y axis so that we can see what is going on
xlim = [-100, 300]
ylim = [-100, 300]
fig, ax = plotData(train_feats, train_y)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
plt.show()

# %% [markdown]
# Check the baseline accuracy on the test set:

# %%
test_pred = NN(train_feats, train_y, test_feats)
acc = Accuracy(test_y, test_pred)
print("Baseline accuracy:", acc*100, "%", "for", nclasses, "classes")
# Out:
# Baseline accuracy: 76.19047619047619 % for 4 classes

# %% [markdown]
# Let us try transforming the features and checking their accuracy. The intuition to using the transformation matrix is to find the basis vectors of the dataset and transform the data to a new coordinate system where the basis vectors are orthogonal. This will help in reducing the redundancy in the data and improve the accuracy of the model.

# %%
transform = np.array([[0.5, -0.5], [0, 2.5]])
print(transform)

train_feats_t = np.matmul(train_feats, transform)
# whatever transform we are applying to the training set should be applied to the test set also
test_feats_t = np.matmul(test_feats, transform)
# Out:
# [[ 0.5 -0.5]
#  [ 0.   2.5]]

# %%
fig, ax = plotData(train_feats_t, train_y)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
plt.show()

# %%
test_pred = NN(train_feats_t, train_y, test_feats_t)
acc = Accuracy(test_y, test_pred)
print("Baseline accuracy:", acc*100, "%", "for", nclasses, "classes")
# Out:
# Baseline accuracy: 80.95238095238095 % for 4 classes

# %% [markdown]
# ## Questions:
# 1. Experiment with different transformation matrices and check the accuracy
# 2. Will the same transform used for these two features also work for other features?

# %%
# 1. A. Different transformation matrices along with their accuracy
transform1 = np.array([[0.5,0],[0.5,2.5]])
train_feats_t = np.matmul(train_feats, transform1.T)
test_feats_t = np.matmul(test_feats, transform1.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 1 = ", Accuracy(test_y, test_pred))

transform2 = np.array([[5,6],[1,2]])
train_feats_t = np.matmul(train_feats, transform2.T)
test_feats_t = np.matmul(test_feats, transform2.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 2 = ", Accuracy(test_y, test_pred))

transform3 = np.array([[1,2], [1,2]])
train_feats_t = np.matmul(train_feats, transform3.T)
test_feats_t = np.matmul(test_feats, transform3.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 3 = ", Accuracy(test_y, test_pred))

transform4 = np.array([[10,9], [100,2]])
train_feats_t = np.matmul(train_feats, transform4.T)
test_feats_t = np.matmul(test_feats, transform4.T)
test_pred = NN(train_feats_t, train_y, test_feats_t)
print("Accuracy after transformation 4 = ", Accuracy(test_y, test_pred))

print("Trying all the possible combination between 0 to 10")
maxAccuracy = -1
x1, y1, x2, y2 = -1, -1, -1, -1
for i1 in range(11):
    for j1 in range(11):
      for i2 in range(11):
            for j2 in range(11):
                t = np.array([[i1, j1], [i2, j2]])
                train_feats_t = np.matmul(train_feats, t.T)
                test_feats_t = np.matmul(test_feats, t.T)
                test_pred = NN(train_feats_t, train_y, test_feats_t)
                acc = Accuracy(test_y, test_pred)
                print("Accuracy after transformation ",[[i1, j1], [i2, j2]], " is = ", acc)
                if(maxAccuracy < acc):
                    maxAccuracy = acc
                    x1, y1, x2, y2 = i1, j1, i2, j2
print("Max Accuarcy obtained at transformation : ", [[x1, y1], [x2, y2]], " i.e Accuracy : ", maxAccuracy)
# Out:
# Streaming output truncated to the last 5000 lines.
# Accuracy after transformation  [[7, 2], [7, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 2], [7, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [7, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [7, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [7, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [8, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 2], [8, 1]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 2], [8, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 2], [8, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [8, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [8, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [8, 6]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 2], [8, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [8, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [8, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [8, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [9, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 2], [9, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [9, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [9, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 2], [9, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [9, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [9, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 2], [9, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [9, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [9, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [9, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [10, 0]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 2], [10, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [10, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 2], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [10, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 2], [10, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 2], [10, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [10, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 2], [10, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 2], [10, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 2], [10, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [0, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [0, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [0, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [0, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [0, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [0, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [0, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [0, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [0, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [0, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [0, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 3], [1, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [1, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [1, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [1, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [1, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [1, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [1, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [1, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [1, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [1, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [1, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [2, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [2, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [2, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [2, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [2, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [2, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [2, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [2, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [2, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [2, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [2, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [3, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [3, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [3, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [3, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [3, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [3, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [3, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [3, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [3, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [3, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [3, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [4, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [4, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [4, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 3], [4, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [4, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [4, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [4, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [4, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [4, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [4, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [4, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [5, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [5, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [5, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [5, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [5, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [5, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [5, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [5, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [5, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [5, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [5, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [6, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [6, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [6, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [6, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [6, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [6, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [6, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [6, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [6, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [6, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [6, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [7, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [7, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [7, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [7, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [7, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [7, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [7, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [7, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [7, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [7, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [7, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [8, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [8, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [8, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [8, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [8, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [8, 5]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 3], [8, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [8, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [8, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [8, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [8, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [9, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [9, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [9, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [9, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [9, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [9, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [9, 6]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 3], [9, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [9, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [9, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [9, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [10, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [10, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [10, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [10, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 3], [10, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 3], [10, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [10, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [10, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 3], [10, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 3], [10, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [0, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [0, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [0, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [0, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [0, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [0, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [0, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [0, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [0, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [0, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [0, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [1, 0]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [1, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [1, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [1, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [1, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [1, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [1, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [1, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [1, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [1, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [1, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [2, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [2, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [2, 2]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 4], [2, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [2, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [2, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [2, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [2, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [2, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [2, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [2, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 4], [3, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [3, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [3, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [3, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [3, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [3, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [3, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [3, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [3, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [3, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [3, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [4, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [4, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [4, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [4, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [4, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [4, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [4, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [4, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [4, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [4, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [4, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [5, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [5, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [5, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [5, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [5, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 4], [5, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [5, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [5, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [5, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [5, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [5, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [6, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [6, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [6, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [6, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [6, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [6, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [6, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [6, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [6, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [6, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [6, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [7, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [7, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [7, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [7, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [7, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [7, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [7, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [7, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [7, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [7, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [8, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [8, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [8, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [8, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [8, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [8, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [8, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [8, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [8, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [8, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [8, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [9, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [9, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [9, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [9, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [9, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 4], [9, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [9, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [9, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 4], [9, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [9, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [10, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 4], [10, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [10, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [10, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 4], [10, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [10, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 4], [10, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 4], [10, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 4], [10, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 4], [10, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [0, 0]]  is =  0.5476190476190477
# Accuracy after transformation  [[7, 5], [0, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [0, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [0, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [0, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [0, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [0, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [0, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [0, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [0, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [0, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [1, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [1, 1]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 5], [1, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [1, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [1, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [1, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [1, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [1, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [1, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [1, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [1, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [2, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [2, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 5], [2, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [2, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [2, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [2, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [2, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [2, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [2, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [2, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [2, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [3, 0]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [3, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [3, 2]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 5], [3, 3]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 5], [3, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [3, 5]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [3, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [3, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [3, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [3, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [3, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [4, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [4, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [4, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [4, 3]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 5], [4, 4]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 5], [4, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [4, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [4, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [4, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [4, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [4, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [5, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [5, 1]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [5, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [5, 3]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 5], [5, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 5], [5, 5]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 5], [5, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [5, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [5, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [5, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [5, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [6, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [6, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [6, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [6, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [6, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 5], [6, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [6, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [6, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [6, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [6, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [6, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [7, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [7, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [7, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [7, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [7, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [7, 5]]  is =  0.5476190476190477
# Accuracy after transformation  [[7, 5], [7, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 5], [7, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [7, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [7, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [7, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [8, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [8, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [8, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [8, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [8, 4]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 5], [8, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [8, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 5], [8, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 5], [8, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [8, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [8, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 5], [9, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [9, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [9, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [9, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [9, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 5], [9, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [9, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 5], [9, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 5], [9, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [9, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [9, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 5], [10, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [10, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [10, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 5], [10, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [10, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [10, 5]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 5], [10, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 5], [10, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 5], [10, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 5], [10, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 5], [10, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [0, 0]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [0, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [0, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [0, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [0, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [0, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [0, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [0, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [0, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [0, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [1, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [1, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [1, 2]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [1, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [1, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [1, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [1, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [1, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [1, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [1, 9]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 6], [1, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 6], [2, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [2, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [2, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [2, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [2, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [2, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [2, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [2, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [2, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [2, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [2, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [3, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [3, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [3, 2]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [3, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [3, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [3, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [3, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [3, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [3, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [3, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [3, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [4, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [4, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [4, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [4, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [4, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [4, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [4, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [4, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [4, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [4, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [4, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [5, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [5, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [5, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [5, 3]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 6], [5, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [5, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [5, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [5, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [5, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [5, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [5, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [6, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [6, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [6, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [6, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [6, 4]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 6], [6, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [6, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [6, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [6, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [6, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [6, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [7, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [7, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [7, 2]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [7, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [7, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [7, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [7, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [7, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [7, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [7, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [7, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [8, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [8, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [8, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [8, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [8, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [8, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [8, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [8, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [8, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [8, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [8, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [9, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [9, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [9, 3]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [9, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [9, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [9, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [9, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 6], [9, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [9, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [9, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 6], [10, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [10, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 6], [10, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [10, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [10, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 6], [10, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 6], [10, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [10, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 6], [10, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 6], [10, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 6], [10, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [0, 0]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [0, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [0, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [0, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [0, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [0, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [0, 6]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [0, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [0, 8]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 7], [0, 9]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 7], [0, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 7], [1, 0]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [1, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [1, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [1, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 7], [1, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [1, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [1, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [1, 7]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [1, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [1, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [1, 10]]  is =  0.7857142857142857
# Accuracy after transformation  [[7, 7], [2, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [2, 1]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 7], [2, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [2, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [2, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [2, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 7], [2, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [2, 7]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [2, 8]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [2, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [2, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [3, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [3, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [3, 2]]  is =  0.5476190476190477
# Accuracy after transformation  [[7, 7], [3, 3]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [3, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [3, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [3, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [3, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [3, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [3, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [3, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[7, 7], [4, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [4, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [4, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [4, 3]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [4, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [4, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [4, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [4, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [4, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [4, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [4, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [5, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [5, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [5, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 7], [5, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [5, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [5, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [5, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [5, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [5, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [5, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [5, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [6, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [6, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [6, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [6, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 7], [6, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [6, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [6, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [6, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [6, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [6, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [6, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 7], [7, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [7, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [7, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [7, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 7], [7, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [7, 6]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [7, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [7, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [7, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [7, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [8, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [8, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [8, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [8, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [8, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[7, 7], [8, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [8, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [8, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [8, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [8, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [8, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [9, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [9, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [9, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [9, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [9, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [9, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [9, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 7], [9, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [9, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [9, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [10, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [10, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [10, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[7, 7], [10, 4]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [10, 5]]  is =  0.7380952380952381
# Accuracy after transformation  [[7, 7], [10, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[7, 7], [10, 7]]  is =  0.5714285714285714
# Accuracy after transformation  [[7, 7], [10, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 7], [10, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[7, 7], [10, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[7, 8], [0, 0]]  is =  0.5476190476190477
# Accuracy after transformation  [[7, 8], [0, 1]]  is =  0.6190476190476191
# Accuracy after transformation  [[7, 8], [0, 2]]  is =  0.6428571428571429
# ...
# Accuracy after transformation  [[10, 9], [3, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [3, 1]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [3, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [3, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 4]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [3, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [3, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [3, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [4, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [4, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [4, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [4, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [4, 5]]  is =  0.5476190476190477
# Accuracy after transformation  [[10, 9], [4, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [4, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [4, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [5, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [5, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [5, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [5, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [5, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [5, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [6, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [6, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [6, 2]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [6, 3]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [6, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [6, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [6, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [6, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [6, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [6, 9]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [6, 10]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [7, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [7, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [7, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [7, 4]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [7, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [7, 6]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [7, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [7, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [7, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [7, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [8, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [8, 1]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [8, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [8, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [8, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [8, 5]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [8, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [8, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [8, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [8, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [8, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [9, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [9, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [9, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [9, 3]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 9], [9, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [9, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [9, 6]]  is =  0.5714285714285714
# Accuracy after transformation  [[10, 9], [9, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [9, 8]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [9, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [9, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 9], [10, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [10, 1]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [10, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [10, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [10, 4]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 9], [10, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 9], [10, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 9], [10, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 9], [10, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 9], [10, 9]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 9], [10, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [0, 0]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [0, 1]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [0, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [0, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [0, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [0, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [0, 6]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [0, 7]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [0, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [0, 9]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 10], [0, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 10], [1, 0]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [1, 1]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [1, 2]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [1, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [1, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 5]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 6]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [1, 8]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [1, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [1, 10]]  is =  0.7619047619047619
# Accuracy after transformation  [[10, 10], [2, 0]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [2, 1]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [2, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [2, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [2, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [2, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [2, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [2, 7]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [2, 8]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [2, 9]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [2, 10]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [3, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [3, 1]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [3, 2]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [3, 3]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [3, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [3, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [3, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [3, 7]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [3, 8]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [3, 9]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [3, 10]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [4, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [4, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [4, 2]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 3]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [4, 4]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [4, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [4, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [4, 10]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [5, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [5, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [5, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [5, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [5, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [5, 5]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [5, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [5, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [5, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [5, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [5, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [6, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [6, 2]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [6, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [6, 4]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 5]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 6]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [6, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [6, 8]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [6, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [6, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [7, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [7, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [7, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [7, 3]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [7, 4]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [7, 5]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [7, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [7, 7]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [7, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [7, 9]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [7, 10]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [8, 0]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [8, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [8, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [8, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [8, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [8, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [8, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [8, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [8, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [8, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [8, 10]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [9, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [9, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [9, 2]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [9, 3]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [9, 4]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [9, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [9, 6]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [9, 7]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [9, 8]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [9, 9]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [9, 10]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [10, 0]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [10, 1]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [10, 2]]  is =  0.7380952380952381
# Accuracy after transformation  [[10, 10], [10, 3]]  is =  0.6904761904761905
# Accuracy after transformation  [[10, 10], [10, 4]]  is =  0.7142857142857143
# Accuracy after transformation  [[10, 10], [10, 5]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [10, 6]]  is =  0.6666666666666666
# Accuracy after transformation  [[10, 10], [10, 7]]  is =  0.5952380952380952
# Accuracy after transformation  [[10, 10], [10, 8]]  is =  0.6428571428571429
# Accuracy after transformation  [[10, 10], [10, 9]]  is =  0.6190476190476191
# Accuracy after transformation  [[10, 10], [10, 10]]  is =  0.6428571428571429
# Max Accuarcy obtained at transformation :  [[0, 3], [2, 3]]  i.e Accuracy :  0.8333333333333334

# %% [markdown]
# 2.A.  The transformation matrix used for two features may not generalize well to other features. This is because different features may have different distributions and relationships within the dataset. A transformation that works well for one pair of features (e.g., hole pixels and boundary pixels) may not optimize the separability of other feature combinations (e.g., hole pixels and convex hull pixels). Therefore, it's essential to tailor transformations to the specific characteristics and relationships of each feature pair.

# %% [markdown]
# > Exercise: Is it possible that adding all 4 features at a time is not the best strategy? Can you think of a better combination of features that can help in improving the accuracy of the model? Maybe you can try adding 2 features at a time and see if that helps.

# %% [markdown]
# A. Instead of adding all four features at once, which may not always yield optimal results due to potential redundancy or conflicting information, a better strategy could involve systematically combining features two at a time. By testing combinations like hole pixels with boundary pixels, or boundary pixels with convex hull pixels, we can identify which pairs provide the most discriminative information for classification tasks. This approach allows for more targeted feature selection and transformation, potentially leading to improved model accuracy.
#
# In summary, the key to leveraging transformation matrices effectively lies in understanding how different transformations impact the separability of features and choosing combinations that enhance classification accuracy based on the dataset's specific characteristics.

# %% [markdown]
# # Data normalization
#
# Sometimes the features of our data have vastly different scales. This will cause the learning algorithm to give more importance to certain features, reducing its performance. Data normalization is a method in which we transform the features so that they have similar scales.
#
# Three commonly used feature scaling techniques are rescaling, mean normalization and z-score normalization. Here, we will talk about the simplest one: rescaling.
#
# $$\begin{equation}
# x' = \frac {x -min(x)} { max(x) - min(x)}
# \end{equation}$$
#
#
#
# For more information, see [this page](https://towardsdatascience.com/data-normalization-in-machine-learning-395fdec69d02).

# %%
def rescale(data):
    return (data - data.min()) / (data.max() - data.min())

# %% [markdown]
# We have to apply the rescaling to each feature individually. Also remember to apply the same transform we are using on the train set to the test set.

# %%
train_feats_rescaled_x = rescale(train_feats[:, 0])
train_feats_rescaled_y = rescale(train_feats[:, 1])
train_feats_rescaled = np.stack((train_feats_rescaled_x, train_feats_rescaled_y), 1)

test_feats_rescaled_x = rescale(test_feats[:, 0])
test_feats_rescaled_y = rescale(test_feats[:, 1])
test_feats_rescaled = np.stack((test_feats_rescaled_x, test_feats_rescaled_y), 1)

# %% [markdown]
# Let us plot the rescaled features:

# %%
fig, ax = plotData(train_feats_rescaled, train_y)

# %% [markdown]
# This type of rescaling makes all the features between 0 and 1.
#
# Let us calculate the accuracy obtained by this transform:

# %%
test_pred = NN(train_feats_rescaled, train_y, test_feats_rescaled)
acc = Accuracy(test_y, test_pred)
print("Accuracy after transform:", acc*100, "%")
# Out:
# Accuracy after transform: 80.95238095238095 %

# %% [markdown]
# All 2D linear transformations can be repreented by a transformation matrix. So what is the matrix associated with the rescaling function? Actually, we cannot represent rescaling with a matrix multiplication, because it is not a linear transform. Rescaling involves shifting the origin of the data, which is not allowed under linear transformations.
#
# We can represent rescaling as a matrix multiplication followed by a vector addition. Let our first feature vector be called X and second feature vector be called Y. Suppose we want to rescale a data point [a,b]
#
# $$ \begin{equation}
#  \left\{  \begin{aligned}a' \\ b' \end{aligned} \right\} =
#  \left\{  \begin{aligned} \frac{a - min(X)}{max(X) - min(X)} \\ \frac{b - min(Y)}{max(Y) - min(Y)} \end{aligned} \right\} =
#  \left\{  \begin{aligned}&\frac{1}{max(X)-min(X)} &0\\ &0 &\frac{1}{max(Y)-min(Y)} \end{aligned}
#  \right\}\left\{  \begin{aligned}a \\ b \end{aligned} \right\} +
#  \left\{  \begin{aligned} \frac{ -min(X)}{max(X) - min(X)} \\ \frac{-min(Y)}{max(Y) - min(Y)} \end{aligned} \right\}
# \end{equation}$$
#
# You can verify this yourself if you wish, though it is not necessary.

# %% [markdown]
# ### 🎯 Lab Summary: What We Learned
#
# **1. Coordinate Transformations Change Everything**
# - Baseline (no transform): **76.19%** accuracy
# - With transformation matrix: **80.95%** accuracy
# - With rescaling: **80.95%** accuracy
# - **Improvement: +4.76%** just by choosing better features!
#
# **2. Why Transformations Matter for ML**
# - Transform changes distances between points
# - K-NN uses distance to find nearest neighbors
# - Different coordinate system → different neighbors → different predictions
#
# ---
#
# ### 📊 Understanding Normalization
#
# **The Problem:** Features with different scales dominate distance calculations.
#
# **Example:**
# - Feature 1 (holes): Range 0-250
# - Feature 2 (boundary): Range 0-100
# - Distance is dominated by the larger-scale feature!
#
# **Solution:** Rescaling brings all features to [0, 1] range.
#
# $$x' = \frac{x - \min(x)}{\max(x) - \min(x)}$$
#
# ---
#
# ### 🔍 Types of Normalization
#
# | Method | Formula | Range | Use Case |
# |--------|---------|-------|----------|
# | **Min-Max (Rescaling)** | $(x - \min) / (\max - \min)$ | [0, 1] | Distance-based algorithms |
# | **Standardization (Z-score)** | $(x - \mu) / \sigma$ | Mean=0, Std=1 | When data has outliers |
# | **Max Abs Scaling** | $x / \max(\|x\|)$ | [-1, 1] | Sparse data |
#
# ---
#
# ### 💡 Practical Tips for Your Projects
#
# **When to Use Transformations:**
# - ✓ Features have very different scales (e.g., age vs salary)
# - ✓ Using distance-based algorithms (K-NN, K-Means)
# - ✓ Want to reduce feature correlation
# - ✓ Need better class separation
#
# **Best Practices:**
# 1. **Always fit on training data only:** Compute min/max from training set
# 2. **Apply same transform to test data:** Use training min/max on test set
# 3. **Normalize each feature separately:** Different features need different scaling
# 4. **Visualize before and after:** Check if classes are better separated
#
# ---
#
# ### 🧮 Quick Reference: Matrix Operations
#
# ```python
# # Transform multiple points at once
# transformed_data = np.matmul(original_data, Transform_Matrix.T)
#
# # Or equivalently
# transformed_data = original_data @ Transform_Matrix.T
#
# # Rescale a feature
# normalized = (feature - feature.min()) / (feature.max() - feature.min())
# ```
#
# ---
#
# ### 🤔 Think About This
#
# **Q:** Why can't we represent rescaling as a matrix multiplication?
#
# **A:** Rescaling shifts the origin: $x' = (x - \min) / (\max - \min)$.
# The subtraction of $\min$ is a translation, not a linear transformation.
# Linear transformations must preserve the origin (0 → 0).
#
# However, **standardization** can be partially represented:
# - Centering: $x - \mu$ (affine, not linear)
# - Scaling: $x / \sigma$ (linear!)
#
# ---
#
# ### 📝 Exercise Ideas
#
# 1. **Experiment with transforms:** Try [[2, 0], [0, 0.5]] - what happens to accuracy?
# 2. **Mix normalization + transformation:** First rescale, then transform
# 3. **Try other features:** Use hull pixels + sum instead of holes + boundary
# 4. **Z-score normalization:** Implement $(x - \mu) / \sigma$ and compare results
# 5. **Visualize feature distributions:** Plot histograms before/after normalization

# %%
# Exercise : 1 - Experiment with the transform [[2, 0], [0, 0.5]]
transform_ex1 = np.array([[2, 0], [0, 0.5]])
train_feats_t_ex1 = np.matmul(train_feats, transform_ex1.T)
test_feats_t_ex1 = np.matmul(test_feats, transform_ex1.T)

test_pred_ex1 = NN(train_feats_t_ex1, train_y, test_feats_t_ex1)
acc_ex1 = Accuracy(test_y, test_pred_ex1)
print(f"Accuracy after transform [[2, 0], [0, 0.5]]: {acc_ex1*100:.2f} %")

# Visualize the transformed data
fig, ax = plotData(train_feats_t_ex1, train_y)
ax.set_xlim(xlim)
ax.set_ylim(ylim)
plt.title("Data after transform [[2, 0], [0, 0.5]]")
plt.show()
# Out:
# Accuracy after transform [[2, 0], [0, 0.5]]: 76.19 %

# %% [markdown]
# **Exercise 1 Analysis:**
#
# The transformation matrix $\begin{bmatrix} 2 & 0 \\ 0 & 0.5 \end{bmatrix}$ scales the first feature (hole pixels) by a factor of 2 and the second feature (boundary pixels) by a factor of 0.5.
#
# Looking at the plot and the accuracy, we can see how this specific scaling affects the data distribution and the nearest neighbor classification performance. You can compare this accuracy to the baseline and the previous transformation results to understand the impact of different scaling factors.

# %%
# 2 - Mix normalization + transformation (Rescale then Transform)
# First, rescale the features
train_feats_rescaled_ex2_x = rescale(train_feats[:, 0])
train_feats_rescaled_ex2_y = rescale(train_feats[:, 1])
train_feats_rescaled_ex2 = np.stack((train_feats_rescaled_ex2_x, train_feats_rescaled_ex2_y), 1)

test_feats_rescaled_ex2_x = rescale(test_feats[:, 0])
test_feats_rescaled_ex2_y = rescale(test_feats[:, 1])
test_feats_rescaled_ex2 = np.stack((test_feats_rescaled_ex2_x, test_feats_rescaled_ex2_y), 1)

# Then apply a transformation matrix (using the one that gave good accuracy before, e.g., [[0, 3], [2, 3]] from previous run)
transform_ex2 = np.array([[0, 3], [2, 3]]) # Example transform from previous run
train_feats_mixed_ex2 = np.matmul(train_feats_rescaled_ex2, transform_ex2.T)
test_feats_mixed_ex2 = np.matmul(test_feats_rescaled_ex2, transform_ex2.T)

test_pred_mixed_ex2 = NN(train_feats_mixed_ex2, train_y, test_feats_mixed_ex2)
acc_mixed_ex2 = Accuracy(test_y, test_pred_mixed_ex2)
print(f"Accuracy after Rescaling then Transform [[0, 3], [2, 3]]: {acc_mixed_ex2*100:.2f} %")

# Visualize the data after both steps
fig, ax = plotData(train_feats_mixed_ex2, train_y)
# Adjust limits as the scaling and transform will change the range
ax.set_xlim(-10, 10)
ax.set_ylim(-10, 10)
plt.title("Data after Rescaling and then Transform [[0, 3], [2, 3]]")
plt.show()
# Out:
# Accuracy after Rescaling then Transform [[0, 3], [2, 3]]: 83.33 %

# %% [markdown]
# **Exercise 2 Analysis:**
#
# Here, we first apply min-max rescaling to bring the features into the [0, 1] range, and then apply a linear transformation. This demonstrates that normalization and linear transformations are different operations and can be combined. The order might matter depending on the specific transformation and the data.

# %%
# 3 - Try other features (hull pixels + sum instead of holes + boundary)

# Feature extraction for hull and sum
train_hull = np.array([getHullPixels(i).sum() for i in train_X])
test_hull = np.array([getHullPixels(i).sum() for i in test_X])
train_sum = np.sum(train_X, (1, 2)) / (28 * 28)
test_sum = np.sum(test_X, (1, 2)) / (28 * 28)

# Create the train and test set using hull and sum
train_feats_ex3 = np.vstack((train_hull, train_sum)).transpose()
test_feats_ex3 = np.vstack((test_hull, test_sum)).transpose()

# Check baseline accuracy with these new features
test_pred_ex3_baseline = NN(train_feats_ex3, train_y, test_feats_ex3)
acc_ex3_baseline = Accuracy(test_y, test_pred_ex3_baseline)
print(f"Baseline accuracy with Hull and Sum features: {acc_ex3_baseline*100:.2f} %")

# Optional: Apply a transformation to these new features and check accuracy
# transform_ex3 = np.array([[...], [...]]) # Define a transformation matrix if desired
# train_feats_t_ex3 = np.matmul(train_feats_ex3, transform_ex3.T)
# test_feats_t_ex3 = np.matmul(test_feats_ex3, transform_ex3.T)
# test_pred_t_ex3 = NN(train_feats_t_ex3, train_y, test_feats_t_ex3)
# acc_t_ex3 = Accuracy(test_y, test_pred_t_ex3)
# print(f"Accuracy after transform on Hull and Sum features: {acc_t_ex3*100:.2f} %")

# Visualize the new features
fig, ax = plotData(train_feats_ex3, train_y, xlabel="hull", ylabel="sum")
# Adjust limits based on the new feature ranges
ax.set_xlim(train_feats_ex3[:, 0].min() - 10, train_feats_ex3[:, 0].max() + 10)
ax.set_ylim(train_feats_ex3[:, 1].min() - 0.1, train_feats_ex3[:, 1].max() + 0.1)
plt.title("Data with Hull and Sum Features")
plt.show()
# Out:
# Baseline accuracy with Hull and Sum features: 66.67 %

# %% [markdown]
# **Exercise 3 Analysis:**
#
# This exercise shows that the choice of features significantly impacts the model's performance. By using different features (hull pixels and the sum of pixel values), we get a new baseline accuracy. Experimenting with transformations on these new features could potentially improve the accuracy further.

# %%
# 4 - Z-score normalization

def zscore_normalize(data):
    mean = np.mean(data)
    std = np.std(data)
    return (data - mean) / std

# Apply z-score normalization to the original features (hole and boundary)
train_feats_zscore_x = zscore_normalize(train_feats[:, 0])
train_feats_zscore_y = zscore_normalize(train_feats[:, 1])
train_feats_zscore = np.stack((train_feats_zscore_x, train_feats_zscore_y), 1)

test_feats_zscore_x = zscore_normalize(test_feats[:, 0])
test_feats_zscore_y = zscore_normalize(test_feats[:, 1])
test_feats_zscore = np.stack((test_feats_zscore_x, test_feats_zscore_y), 1)


test_pred_zscore = NN(train_feats_zscore, train_y, test_feats_zscore)
acc_zscore = Accuracy(test_y, test_pred_zscore)
print(f"Accuracy after Z-score normalization: {acc_zscore*100:.2f} %")

# Visualize the z-score normalized features
fig, ax = plotData(train_feats_zscore, train_y, xlabel="hole (z-score)", ylabel="bound (z-score)")
# Z-score typically centers data around 0 with std deviation 1. Adjust limits accordingly.
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
plt.title("Data after Z-score Normalization")
plt.show()
# Out:
# Accuracy after Z-score normalization: 78.57 %

# %% [markdown]
# **Exercise 4 Analysis:**
#
# Z-score normalization transforms features to have a mean of 0 and a standard deviation of 1. This is another common normalization technique that can be useful, especially when dealing with data that has outliers. Compare the accuracy obtained with z-score normalization to that of min-max rescaling and the baseline.

# %%
# 5 - Visualize feature distributions

# Visualize distributions of original features
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(train_feats[:, 0], bins=20)
plt.title("Distribution of Hole Pixels (Original)")
plt.xlabel("Hole Pixels")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(train_feats[:, 1], bins=20)
plt.title("Distribution of Boundary Pixels (Original)")
plt.xlabel("Boundary Pixels")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# Visualize distributions after Rescaling
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(train_feats_rescaled[:, 0], bins=20)
plt.title("Distribution of Hole Pixels (Rescaled)")
plt.xlabel("Hole Pixels (Rescaled)")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(train_feats_rescaled[:, 1], bins=20)
plt.title("Distribution of Boundary Pixels (Rescaled)")
plt.xlabel("Boundary Pixels (Rescaled)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# Visualize distributions after Z-score normalization
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(train_feats_zscore[:, 0], bins=20)
plt.title("Distribution of Hole Pixels (Z-score)")
plt.xlabel("Hole Pixels (Z-score)")
plt.ylabel("Frequency")

plt.subplot(1, 2, 2)
plt.hist(train_feats_zscore[:, 1], bins=20)
plt.title("Distribution of Boundary Pixels (Z-score)")
plt.xlabel("Boundary Pixels (Z-score)")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Exercise 5 Analysis:**
#
# These histograms show how the distribution of the features changes after rescaling and z-score normalization. Notice how rescaling compresses the data into the [0, 1] range, while z-score normalization centers the data around 0 and scales it according to the standard deviation. Visualizing feature distributions is a good practice to understand the effect of normalization techniques.
